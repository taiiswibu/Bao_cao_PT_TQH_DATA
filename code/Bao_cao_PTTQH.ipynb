# %% [markdown]
# # Khai Báo Thư Viện

# %%
import yfinance as yf
import pandas as pd 
import os
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Tiền xử lý dữ liệu

# %%
file_path = r'D:\Code\Bao_cao_PT_TQH_DATA\data\AAPL.xlsx' # doc file tu excel
data = pd.read_excel(file_path, sheet_name= 'AAPL - Income Statement FY')
data.head()
# Out:
#   Income Statement           Unnamed: 1           Unnamed: 2  \
# 0          Company        AAPL (NASDAQ)                  NaN
# 1         Currency                  USD                  NaN
# 2           Period                   FY                  NaN
# 3             Date  2023-09-30 00:00:00  2022-09-24 00:00:00
# 4              NaN                  NaN                  NaN
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3  2021-09-25 00:00:00  2020-09-26 00:00:00  2019-09-28 00:00:00
# 4                  NaN                  NaN                  NaN
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# ...

# %%
data = data.dropna()
data.head()
# Out:
#      Income Statement           Unnamed: 1           Unnamed: 2  \
# 3                Date  2023-09-30 00:00:00  2022-09-24 00:00:00
# 5             Revenue         383285000000         394328000000
# 7     Cost Of Revenue         214137000000         223546000000
# 8        Gross Profit         169148000000         170782000000
# 9  Gross Profit Ratio             0.441311             0.433096
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 3  2021-09-25 00:00:00  2020-09-26 00:00:00  2019-09-28 00:00:00
# 5         365817000000         274515000000         260174000000
# 7         212981000000         169559000000         161782000000
# 8         152836000000         104956000000          98392000000
# 9             0.417794             0.382332             0.378178
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 3  2018-09-29 00:00:00  2017-09-30 00:00:00  2016-09-24 00:00:00
# ...

# %%
null_count = data.isnull().values.sum()  # Tính tổng số giá trị null trong DataFrame
print(f"Số lượng giá trị null trong DataFrame: {null_count}")
# Out:
# Số lượng giá trị null trong DataFrame: 0

# %%
column = data.iloc[0] # lay hang chi so 3
column
# Out:
# Income Statement                   Date
# Unnamed: 1          2023-09-30 00:00:00
# Unnamed: 2          2022-09-24 00:00:00
# Unnamed: 3          2021-09-25 00:00:00
# Unnamed: 4          2020-09-26 00:00:00
# Unnamed: 5          2019-09-28 00:00:00
# Unnamed: 6          2018-09-29 00:00:00
# Unnamed: 7          2017-09-30 00:00:00
# Unnamed: 8          2016-09-24 00:00:00
# Unnamed: 9          2015-09-26 00:00:00
# Unnamed: 10         2014-09-27 00:00:00
# Unnamed: 11         2013-09-28 00:00:00
# Unnamed: 12         2012-09-29 00:00:00
# Unnamed: 13         2011-09-24 00:00:00
# Unnamed: 14         2010-09-25 00:00:00
# Unnamed: 15         2009-09-26 00:00:00
# Unnamed: 16         2008-09-27 00:00:00
# Unnamed: 17         2007-09-29 00:00:00
# Unnamed: 18         2006-09-30 00:00:00
# Unnamed: 19         2005-09-24 00:00:00
# Name: 3, dtype: object

# %%
# Đổi tên các cột trong DataFrame
data.rename(columns=column, inplace=True)
data.head()
# Out:
#                  Date  2023-09-30 00:00:00  2022-09-24 00:00:00  \
# 3                Date  2023-09-30 00:00:00  2022-09-24 00:00:00
# 5             Revenue         383285000000         394328000000
# 7     Cost Of Revenue         214137000000         223546000000
# 8        Gross Profit         169148000000         170782000000
# 9  Gross Profit Ratio             0.441311             0.433096
#
#    2021-09-25 00:00:00  2020-09-26 00:00:00  2019-09-28 00:00:00  \
# 3  2021-09-25 00:00:00  2020-09-26 00:00:00  2019-09-28 00:00:00
# 5         365817000000         274515000000         260174000000
# 7         212981000000         169559000000         161782000000
# 8         152836000000         104956000000          98392000000
# 9             0.417794             0.382332             0.378178
#
#    2018-09-29 00:00:00  2017-09-30 00:00:00  2016-09-24 00:00:00  \
# 3  2018-09-29 00:00:00  2017-09-30 00:00:00  2016-09-24 00:00:00
# ...

# %%
# Xóa hàng với chỉ số là 3
data.drop(index=3, inplace=True)
# Hiển thị DataFrame 
data.head()
# Out:
#                                  Date 2023-09-30 00:00:00 2022-09-24 00:00:00  \
# 5                             Revenue        383285000000        394328000000
# 7                     Cost Of Revenue        214137000000        223546000000
# 8                        Gross Profit        169148000000        170782000000
# 9                  Gross Profit Ratio            0.441311            0.433096
# 11  Research And Development Expenses         29915000000         26251000000
#
#    2021-09-25 00:00:00 2020-09-26 00:00:00 2019-09-28 00:00:00  \
# 5         365817000000        274515000000        260174000000
# 7         212981000000        169559000000        161782000000
# 8         152836000000        104956000000         98392000000
# 9             0.417794            0.382332            0.378178
# 11         21914000000         18752000000         16217000000
#
#    2018-09-29 00:00:00 2017-09-30 00:00:00 2016-09-24 00:00:00  \
# ...

# %%
csv = r'D:\Code\Bao_cao_PT_TQH_DATA\data\AAPL_income_statement.csv'  
# Lưu DataFrame vào tệp CSV
data.to_csv(csv, index=False)
print(f"Dữ liệu đã được lưu vào {csv}")
data.head()
# Out:
# Dữ liệu đã được lưu vào D:\Code\Bao_cao_PT_TQH_DATA\data\AAPL_income_statement.csv
#                                  Date 2023-09-30 00:00:00 2022-09-24 00:00:00  \
# 5                             Revenue        383285000000        394328000000
# 7                     Cost Of Revenue        214137000000        223546000000
# 8                        Gross Profit        169148000000        170782000000
# 9                  Gross Profit Ratio            0.441311            0.433096
# 11  Research And Development Expenses         29915000000         26251000000
#
#    2021-09-25 00:00:00 2020-09-26 00:00:00 2019-09-28 00:00:00  \
# 5         365817000000        274515000000        260174000000
# 7         212981000000        169559000000        161782000000
# 8         152836000000        104956000000         98392000000
# 9             0.417794            0.382332            0.378178
# 11         21914000000         18752000000         16217000000
#
# ...

# %% [markdown]
# # 2. Phân tích và trực quan hóa dữ liệu:

# %% [markdown]
# Báo cáo thu nhập, còn được gọi là báo cáo lãi lỗ (P&L), cung cấp cái nhìn tổng quan về hiệu quả tài chính của một doanh nghiệp trong một khoảng thời gian nhất định. Báo cáo này tóm tắt các khoản doanh thu và chi phí, giúp xác định lợi nhuận hoặc lỗ trong kỳ báo cáo.

# %% [markdown]
# - Hiểu rõ doanh thu
# - Xác định chi phí
# - Lợi nhuận hoặc lỗ

# %% [markdown]
# Thông tin trên một báo cáo thu nhập
# - Doanh thu: Số tiền doanh nghiệp thu được trong kỳ báo cáo.
# - Chi phí: Số tiền chi tiêu trong kỳ báo cáo.
# - Giá vốn hàng bán (COGS): Chi phí sản xuất hàng hóa hoặc dịch vụ mà doanh nghiệp bán.
# - Lợi nhuận gộp: Tính bằng doanh thu trừ đi giá vốn hàng bán.
# - Thu nhập hoạt động: Lợi nhuận gộp trừ chi phí hoạt động.
# - Thu nhập trước thuế: Lợi nhuận hoạt động trừ chi phí không hoạt động.
# - Thu nhập ròng: Thu nhập trước thuế trừ thuế.
# - Thu nhập trên mỗi cổ phiếu (EPS): Chia thu nhập ròng cho tổng số cổ phiếu đang lưu hành.
# - Khấu hao: Mức độ mà tài sản bị mất giá trị theo thời gian.
# - EBITDA: Thu nhập trước lãi vay, thuế, khấu hao và khấu hao.

# %%
file= r'D:\Code\Bao_cao_PT_TQH_DATA\data\AAPL_income_statement.csv'
df = pd.read_csv(file, index_col=0)
df.head()
# Out:
#                                    2023-09-30 00:00:00  2022-09-24 00:00:00  \
# Date
# Revenue                                   3.832850e+11         3.943280e+11
# Cost Of Revenue                           2.141370e+11         2.235460e+11
# Gross Profit                              1.691480e+11         1.707820e+11
# Gross Profit Ratio                        4.413113e-01         4.330963e-01
# Research And Development Expenses         2.991500e+10         2.625100e+10
#
#                                    2021-09-25 00:00:00  2020-09-26 00:00:00  \
# Date
# Revenue                                   3.658170e+11         2.745150e+11
# Cost Of Revenue                           2.129810e+11         1.695590e+11
# Gross Profit                              1.528360e+11         1.049560e+11
# Gross Profit Ratio                        4.177936e-01         3.823325e-01
# Research And Development Expenses         2.191400e+10         1.875200e+10
#
# ...

# %%
# thong ke mo ta
df.describe()
# Out:
#        2023-09-30 00:00:00  2022-09-24 00:00:00  2021-09-25 00:00:00  \
# count         2.700000e+01         2.700000e+01         2.700000e+01
# mean          6.149744e+10         6.301288e+10         5.820167e+10
# std           9.777363e+10         1.006866e+11         9.365247e+10
# min          -5.650000e+08        -3.340000e+08        -6.000000e+07
# 25%           3.847894e-01         3.820715e-01         3.732317e-01
# 50%           1.574423e+10         1.621596e+10         1.452700e+10
# 75%           1.053655e+11         1.094530e+11         1.018145e+11
# max           3.832850e+11         3.943280e+11         3.658170e+11
#
#        2020-09-26 00:00:00  2019-09-28 00:00:00  2018-09-29 00:00:00  \
# count         2.700000e+01         2.700000e+01         2.700000e+01
# mean          4.304742e+10         4.110670e+10         4.229496e+10
# std           7.064072e+10         6.687340e+10         6.811292e+10
# ...

# %%
# Lấy các giá trị quan trọng
revenue = df.loc['Revenue']
cost_of_revenue = df.loc['Cost Of Revenue']
gross_profit = df.loc['Gross Profit']
operating_income = df.loc['Operating Income']
net_income = df.loc['Net Income']
gross_profit_ratio = df.loc['Gross Profit Ratio']
ebitda = df.loc['Ebitda']
ebitda_ratio = df.loc['Ebitdaratio']
net_income_ratio = df.loc['Net Income Ratio']
eps = df.loc['Eps']

# %%
years = [
    '30/09/2023', '24/09/2022', '25/09/2021', 
    '26/09/2020', '28/09/2019', '29/09/2018', 
    '30/09/2017', '24/09/2016', '26/09/2015', 
    '27/09/2014', '28/09/2013', '29/09/2012', 
    '24/09/2011', '25/09/2010', '26/09/2009', 
    '27/09/2008', '29/09/2007', '30/09/2006', 
    '24/09/2005'
]

# Chuyển đổi danh sách ngày tháng thành datetime
years_datetime = pd.to_datetime(years, format='%d/%m/%Y')

# Lấy danh sách năm
years_only = years_datetime.tolist()
years_only = [year.split('/')[-1] for year in years]
years_only
# Out:
# ['2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005']

# %% [markdown]
# Doanh thu và Chi phí doanh thu
# - Doanh thu (Revenue):Doanh thu là tổng số tiền mà một công ty kiếm được từ việc bán sản phẩm hoặc cung cấp dịch vụ trong một khoảng thời gian nhất định
# - Chi phí doanh thu (Cost of Revenue):là các chi phí trực tiếp liên quan đến việc sản xuất và cung cấp hàng hóa hoặc dịch vụ mà công ty bán ra. Điều này bao gồm các chi phí như nguyên vật liệu, lao động, và các chi phí sản xuất trực tiếp khác

# %%
plt.figure(figsize=(10, 5))
# Độ rộng của các cột
width = 0.35

# Tạo vị trí cho các cột dựa trên số năm
x = np.arange(len(years_only))  # Vị trí cho các năm trên trục X

# Vẽ các cột cho Doanh thu và Chi phí doanh thu
plt.bar(x - width/2, revenue, width=width, color='g', label='Doanh thu')
plt.bar(x + width/2, cost_of_revenue, width=width, color='r', label='Chi phí doanh thu')

# Thiết lập tiêu đề và nhãn
plt.title('Biểu đồ so sánh Doanh thu và Chi phí doanh thu')
plt.xlabel('Năm')
plt.ylabel('Giá trị (trăm tỷ USD)')

# Đặt lại nhãn trục X thành các năm
plt.xticks(x, years_only, rotation=45)

# Hiển thị lưới cho trục Y
plt.grid(True, axis='y')

# Thêm chú thích (legend)
plt.legend()

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()

# %% [markdown]
# Tỷ lệ lợi nhuận gộp (Gross Profit Ratio) là một chỉ số tài chính cho biết phần trăm lợi nhuận gộp mà một công ty tạo ra từ doanh thu của mình. Nó được sử dụng để đánh giá hiệu quả kinh doanh và khả năng sinh lời của công ty.
# - Lợi nhuận gộp (Gross Profit) là doanh thu trừ đi chi phí bán hàng (Cost of Goods Sold - COGS).
# - Doanh thu (Revenue) là tổng doanh thu từ việc bán hàng hoặc dịch vụ.
# - Tỷ lệ lợi nhuận gộp cao cho thấy công ty có khả năng kiểm soát chi phí bán hàng tốt và có thể tạo ra nhiều lợi nhuận từ doanh thu của mình.
# - Tỷ lệ này cũng giúp so sánh hiệu quả hoạt động của các công ty trong cùng một ngành.
#
# ![image.png](attachment:image.png)

# %%
# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(years_only, gross_profit_ratio, marker='o', color='b')
plt.title('Biểu đồ Tỷ lệ lợi nhuận gộp')
plt.xlabel('Năm')
plt.ylabel('Tỷ lệ lợi nhuận gộp (%)')
plt.xticks(years_only,rotation=45)
plt.grid()
plt.tight_layout()
plt.show()
